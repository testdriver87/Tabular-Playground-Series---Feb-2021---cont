# %% [markdown]
# # Tabular Playground Series - Feb 2021

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ## Read datasets

# %%
train = pd.read_csv('train.zip', index_col='id')
display(train.sample(2))
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5  \
# id                                                        ...
# 56956     A    B    A    A    B    B    A    E    E    L  ...  0.209124
# 401413    A    A    A    C    B    B    A    E    E    K  ...  0.203811
#
#            cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# id
# 56956   0.340411  0.679454  0.358233  0.332291  0.295032  0.360515  0.264896
# 401413  0.353985  0.402373  0.267595  0.305343  0.396868  0.227666  0.249721
#
#           cont13    target
# id
# 56956   0.700195  8.960819
# 401413  0.556236  6.817004
#
# [2 rows x 25 columns]

# %%
test = pd.read_csv('test.zip', index_col='id')
display(test.sample(2))
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont4  \
# id                                                        ...
# 363264    A    A    A    C    B    B    A    E    G    F  ...  0.277032
# 264626    A    B    A    C    B    B    A    E    E    I  ...  0.491876
#
#            cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# id
# 363264  0.595995  0.985877  0.696328  0.691716  0.619671  0.652784  0.928903
# 264626  0.249672  0.256255  0.443257  0.380537  0.354388  0.247124  0.448589
#
#           cont12    cont13
# id
# 363264  0.324949  0.725156
# 264626  0.287455  0.220694
#
# [2 rows x 24 columns]

# %%
submission = pd.read_csv('sample_submission.csv', index_col='id')
display(submission.sample(2))
# Out:
#         target
# id
# 146895     0.5
# 124637     0.5

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Feature Selection

# %%
# !pip install -q lofo-importance
from lofo import LOFOImportance, Dataset, plot_importance
dataset = Dataset(df=train, target='target', features=[col for col in train.columns if col != 'target'])
cv = KFold(n_splits=5, shuffle=True, random_state=42)
lofo_imp = LOFOImportance(dataset, cv=cv, scoring="neg_root_mean_squared_error")
importance_df = lofo_imp.get_importance()
plot_importance(importance_df, figsize=(6,10))

# %%
train = train.drop(['cat4', 'cat5', 'cat7', 'cont2', 'cont4', 'cont7', 'cont12'], axis=1)
test = test.drop(['cat4', 'cat5', 'cat7', 'cont2', 'cont4', 'cont7', 'cont12'], axis=1)

# %% [markdown]
# ## Split

# %%
X = train.drop(['target'], axis=1)
y = train.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.20, random_state = 42)

# %% [markdown]
# ## LazyPredict

# %%
# !pip install -U -q pip
# !pip install -U -q setuptools
# !pip install -q lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=True)
models,predictions = reg.fit(X_train, X_test, y_train, y_test)

# %%
print(models)

# %% [markdown]
# ## EvalML

# %%
# !pip install -U -q pip
# !pip install -U -q setuptools
# !pip install -q evalml

# %%
import evalml
from evalml.automl import AutoMLSearch

# %%
X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(X, y, problem_type='regression')

# %%
automl = AutoMLSearch(X_train=X_train, y_train=y_train, 
                      problem_type='regression',
                      objective='Root Mean Squared Error',
                      additional_objectives=['R2', 'MSE'],
                      optimize_thresholds=True,
                      max_batches=2,
                      ensembling=True)
automl.search()

# %%
automl.rankings

# %%
automl.describe_pipeline(automl.rankings.iloc[0]["id"])

# %%
automl.best_pipeline.fit(X_train, y_train)
automl.best_pipeline.score(X_test, y_test, objectives=["Root Mean Squared Error", "R2", "MSE"])

# %%
submission['target'] = automl.best_pipeline.predict(test)
submission.to_csv('submission_evalml .csv')

# %%
submission

# %% [markdown]
# ## AutoGluon

# %%
# !pip install -U -q pip
# !pip install -U -q setuptools
# !pip install -U -q mxnet
# !pip install -q autogluon
from autogluon.tabular import TabularPredictor

# %%
predictor = TabularPredictor(label='target', 
                             problem_type='regression', 
                             eval_metric='root_mean_squared_error'
                             ).fit(train, 
                                   time_limit=1800, 
                                   presets='high_quality_fast_inference_only_refit'
                                   )
# Out:
# /opt/conda/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# No path specified. Models will be saved in: "AutogluonModels/ag-20210422_130837/"
# Presets specified: ['high_quality_fast_inference_only_refit']
# Beginning AutoGluon training ... Time limit = 1800s
# AutoGluon will save models to "AutogluonModels/ag-20210422_130837/"
# AutoGluon Version:  0.1.0
# Train Data Rows:    300000
# Train Data Columns: 17
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# NumExpr defaulting to 4 threads.
# 	Available Memory:                    17961.14 MB
# 	Train Data (Original)  Memory Usage: 145.8 MB (0.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 10 | ['cont0', 'cont1', 'cont3', 'cont5', 'cont6', ...]
# 		('object', []) :  7 | ['cat0', 'cat1', 'cat2', 'cat3', 'cat6', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) :  7 | ['cat0', 'cat1', 'cat2', 'cat3', 'cat6', ...]
# 		('float', [])    : 10 | ['cont0', 'cont1', 'cont3', 'cont5', 'cont6', ...]
# 	3.7s = Fit runtime
# 	17 features in original data used to generate 17 features in processed data.
# 	Train Data (Processed) Memory Usage: 26.1 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 4.3s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 897.84s of the 1795.68s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 120 due to low memory. Expected memory usage reduced from 37.29% -> 15.0% of available memory...
# 	Warning: Model is expected to require 453.9s to train, which exceeds the maximum time limit of 71.8s, skipping model...
# 	Time limit exceeded... Skipping RandomForestMSE_BAG_L1.
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 882.17s of the 1780.01s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 75 due to low memory. Expected memory usage reduced from 59.35% -> 15.0% of available memory...
# 	Warning: Reducing model 'n_estimators' from 300 -> 75 due to low memory. Expected memory usage reduced from 59.66% -> 15.0% of available memory...
# 	Warning: Model is expected to require 134.6s to train, which exceeds the maximum time limit of 71.5s, skipping model...
# 	Time limit exceeded... Skipping ExtraTreesMSE_BAG_L1.
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 797.18s of the 1695.02s of remaining time.
# 	-0.9528	 = Validation root_mean_squared_error score
# 	32.1s	 = Training runtime
# 	149.5s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 615.42s of the 1513.26s of remaining time.
# 	-0.9536	 = Validation root_mean_squared_error score
# 	26.14s	 = Training runtime
# 	141.73s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 447.37s of the 1345.22s of remaining time.
# 	Ran out of time, early stopping on iteration 152. Best iteration is:
# 	[152]	train_set's rmse: 0.841881	valid_set's rmse: 0.844828
# 	Ran out of time, early stopping on iteration 187. Best iteration is:
# 	[187]	train_set's rmse: 0.839208	valid_set's rmse: 0.847019
# 	Ran out of time, early stopping on iteration 172. Best iteration is:
# 	[172]	train_set's rmse: 0.839631	valid_set's rmse: 0.851572
# 	Ran out of time, early stopping on iteration 272. Best iteration is:
# 	[272]	train_set's rmse: 0.835191	valid_set's rmse: 0.847726
# 	Ran out of time, early stopping on iteration 202. Best iteration is:
# 	[202]	train_set's rmse: 0.838291	valid_set's rmse: 0.849648
# 	Ran out of time, early stopping on iteration 213. Best iteration is:
# 	[212]	train_set's rmse: 0.837303	valid_set's rmse: 0.851686
# 	-0.8465	 = Validation root_mean_squared_error score
# 	408.79s	 = Training runtime
# 	5.45s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 32.97s of the 930.81s of remaining time.
# 	Ran out of time, early stopping on iteration 8. Best iteration is:
# 	[8]	train_set's rmse: 0.876949	valid_set's rmse: 0.875932
# 	Ran out of time, early stopping on iteration 8. Best iteration is:
# 	[8]	train_set's rmse: 0.876803	valid_set's rmse: 0.875116
# 	Ran out of time, early stopping on iteration 8. Best iteration is:
# 	[8]	train_set's rmse: 0.876085	valid_set's rmse: 0.882362
# 	Ran out of time, early stopping on iteration 10. Best iteration is:
# 	[10]	train_set's rmse: 0.874545	valid_set's rmse: 0.876646
# 	Ran out of time, early stopping on iteration 8. Best iteration is:
# 	[8]	train_set's rmse: 0.876359	valid_set's rmse: 0.879638
# 	Ran out of time, early stopping on iteration 9. Best iteration is:
# 	[9]	train_set's rmse: 0.87536	valid_set's rmse: 0.879666
# 	Ran out of time, early stopping on iteration 10. Best iteration is:
# 	[10]	train_set's rmse: 0.875493	valid_set's rmse: 0.868466
# 	Ran out of time, early stopping on iteration 9. Best iteration is:
# 	[9]	train_set's rmse: 0.875604	valid_set's rmse: 0.878077
# 	Ran out of time, early stopping on iteration 10. Best iteration is:
# 	[10]	train_set's rmse: 0.875289	valid_set's rmse: 0.871014
# 	Ran out of time, early stopping on iteration 12. Best iteration is:
# 	[12]	train_set's rmse: 0.873354	valid_set's rmse: 0.871462
# 	-0.8758	 = Validation root_mean_squared_error score
# 	31.58s	 = Training runtime
# 	0.6s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 0.63s of the 898.47s of remaining time.
# 	Time limit exceeded... Skipping CatBoost_BAG_L1.
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 897.77s of remaining time.
# 	-0.8465	 = Validation root_mean_squared_error score
# 	5.18s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 892.55s of the 892.52s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 119 due to low memory. Expected memory usage reduced from 37.69% -> 15.0% of available memory...
# 	Warning: Model is expected to require 703.0s to train, which exceeds the maximum time limit of 71.4s, skipping model...
# 	Time limit exceeded... Skipping RandomForestMSE_BAG_L2.
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 868.64s of the 868.61s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 74 due to low memory. Expected memory usage reduced from 60.31% -> 15.0% of available memory...
# 	Warning: Reducing model 'n_estimators' from 74 -> 42 due to low time. Expected time usage reduced from 120.2s -> 69.5s...
# 	Warning: Reducing model 'n_estimators' from 300 -> 74 due to low memory. Expected memory usage reduced from 60.56% -> 15.0% of available memory...
# 	Warning: Model is expected to require 160.6s to train, which exceeds the maximum time limit of 71.0s, skipping model...
# 	Time limit exceeded... Skipping ExtraTreesMSE_BAG_L2.
# Fitting model: KNeighborsUnif_BAG_L2 ... Training model for up to 790.23s of the 790.21s of remaining time.
# 	-0.922	 = Validation root_mean_squared_error score
# 	44.53s	 = Training runtime
# 	362.02s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L2 ... Training model for up to 383.54s of the 383.51s of remaining time.
# 	Time limit exceeded... Skipping KNeighborsDist_BAG_L2.
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 344.35s of the 344.32s of remaining time.
# 	-0.8465	 = Validation root_mean_squared_error score
# 	204.04s	 = Training runtime
# 	1.38s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 138.77s of the 138.75s of remaining time.
# 	Ran out of time, early stopping on iteration 49. Best iteration is:
# 	[49]	train_set's rmse: 0.846834	valid_set's rmse: 0.852188
# 	Ran out of time, early stopping on iteration 56. Best iteration is:
# 	[56]	train_set's rmse: 0.847457	valid_set's rmse: 0.841219
# 	Ran out of time, early stopping on iteration 67. Best iteration is:
# 	[67]	train_set's rmse: 0.845409	valid_set's rmse: 0.852602
# 	Ran out of time, early stopping on iteration 53. Best iteration is:
# 	[53]	train_set's rmse: 0.84707	valid_set's rmse: 0.845948
# 	Ran out of time, early stopping on iteration 47. Best iteration is:
# 	[47]	train_set's rmse: 0.847811	valid_set's rmse: 0.84693
# 	Ran out of time, early stopping on iteration 53. Best iteration is:
# 	[53]	train_set's rmse: 0.847089	valid_set's rmse: 0.849146
# 	Ran out of time, early stopping on iteration 76. Best iteration is:
# 	[76]	train_set's rmse: 0.845321	valid_set's rmse: 0.849998
# 	Ran out of time, early stopping on iteration 66. Best iteration is:
# 	[66]	train_set's rmse: 0.845288	valid_set's rmse: 0.855078
# 	Ran out of time, early stopping on iteration 66. Best iteration is:
# 	[66]	train_set's rmse: 0.846824	valid_set's rmse: 0.840453
# 	Ran out of time, early stopping on iteration 93. Best iteration is:
# 	[93]	train_set's rmse: 0.84522	valid_set's rmse: 0.844751
# 	-0.8478	 = Validation root_mean_squared_error score
# 	132.92s	 = Training runtime
# 	1.52s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 4.21s of the 4.18s of remaining time.
# 	Time limit exceeded... Skipping CatBoost_BAG_L2.
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 3.69s of the 3.66s of remaining time.
# 	Time limit exceeded... Skipping XGBoost_BAG_L2.
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -4.36s of remaining time.
# 	-0.8463	 = Validation root_mean_squared_error score
# 	5.57s	 = Training runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 1810.09s ...
# Fitting model: KNeighborsUnif_BAG_L1_FULL ...
# 	1.53s	 = Training runtime
# Fitting model: KNeighborsDist_BAG_L1_FULL ...
# 	1.93s	 = Training runtime
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	50.26s	 = Training runtime
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	2.21s	 = Training runtime
# Fitting model: WeightedEnsemble_L2_FULL ...
# 	-0.8465	 = Validation root_mean_squared_error score
# 	0.01s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsUnif_BAG_L2_FULL ...
# 	1.83s	 = Training runtime
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	39.24s	 = Training runtime
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	29.33s	 = Training runtime
# Fitting model: WeightedEnsemble_L3_FULL ...
# 	-0.8463	 = Validation root_mean_squared_error score
# 	0.54s	 = Training runtime
# 	0.01s	 = Validation runtime
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20210422_130837/")

# %%
predictor.leaderboard()
# Out:
#                          model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0          WeightedEnsemble_L3  -0.846289     660.687930  752.759294                0.006846           5.566365            3      False          9
# 1              LightGBM_BAG_L2  -0.846454     298.660806  702.663576                1.378855         204.044627            2      False          7
# 2              LightGBM_BAG_L1  -0.846537       5.450410  408.794699                5.450410         408.794699            1      False          3
# 3          WeightedEnsemble_L2  -0.846537       5.457523  413.979220                0.007113           5.184520            2      False          5
# 4            LightGBMXT_BAG_L2  -0.847844     298.797114  631.543463                1.515164         132.924514            2      False          8
# 5            LightGBMXT_BAG_L1  -0.875848       0.602385   31.577895                0.602385          31.577895            1      False          4
# 6        KNeighborsUnif_BAG_L2  -0.921975     659.302229  543.148301              362.020279          44.529352            2      False          6
# 7        KNeighborsUnif_BAG_L1  -0.952763     149.501869   32.103163              149.501869          32.103163            1      False          1
# 8        KNeighborsDist_BAG_L1  -0.953635     141.727287   26.143192              141.727287          26.143192            1      False          2
# 9     WeightedEnsemble_L3_FULL        NaN            NaN   97.543239                0.009884           0.543953            3       True         18
# 10    WeightedEnsemble_L2_FULL        NaN            NaN   50.270848                0.026430           0.012013            2       True         14
# 11        LightGBM_BAG_L2_FULL        NaN            NaN   95.166056                     NaN          39.236059            2       True         16
# 12        LightGBM_BAG_L1_FULL        NaN            NaN   50.258835                     NaN          50.258835            1       True         12
# 13      LightGBMXT_BAG_L2_FULL        NaN            NaN   85.264698                     NaN          29.334701            2       True         17
# 14      LightGBMXT_BAG_L1_FULL        NaN            NaN    2.207673                     NaN           2.207673            1       True         13
# 15  KNeighborsUnif_BAG_L2_FULL        NaN            NaN   57.763227                     NaN           1.833230            2       True         15
# 16  KNeighborsUnif_BAG_L1_FULL        NaN            NaN    1.532850                     NaN           1.532850            1       True         10
# 17  KNeighborsDist_BAG_L1_FULL        NaN            NaN    1.930640                     NaN           1.930640            1       True         11
# /opt/conda/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                          model  score_val  pred_time_val    fit_time  \
# 0          WeightedEnsemble_L3  -0.846289     660.687930  752.759294
# 1              LightGBM_BAG_L2  -0.846454     298.660806  702.663576
# 2              LightGBM_BAG_L1  -0.846537       5.450410  408.794699
# 3          WeightedEnsemble_L2  -0.846537       5.457523  413.979220
# 4            LightGBMXT_BAG_L2  -0.847844     298.797114  631.543463
# 5            LightGBMXT_BAG_L1  -0.875848       0.602385   31.577895
# 6        KNeighborsUnif_BAG_L2  -0.921975     659.302229  543.148301
# 7        KNeighborsUnif_BAG_L1  -0.952763     149.501869   32.103163
# 8        KNeighborsDist_BAG_L1  -0.953635     141.727287   26.143192
# 9     WeightedEnsemble_L3_FULL        NaN            NaN   97.543239
# 10    WeightedEnsemble_L2_FULL        NaN            NaN   50.270848
# 11        LightGBM_BAG_L2_FULL        NaN            NaN   95.166056
# 12        LightGBM_BAG_L1_FULL        NaN            NaN   50.258835
# 13      LightGBMXT_BAG_L2_FULL        NaN            NaN   85.264698
# 14      LightGBMXT_BAG_L1_FULL        NaN            NaN    2.207673
# 15  KNeighborsUnif_BAG_L2_FULL        NaN            NaN   57.763227
# 16  KNeighborsUnif_BAG_L1_FULL        NaN            NaN    1.532850
# 17  KNeighborsDist_BAG_L1_FULL        NaN            NaN    1.930640
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.006846           5.566365            3      False
# 1                 1.378855         204.044627            2      False
# 2                 5.450410         408.794699            1      False
# 3                 0.007113           5.184520            2      False
# 4                 1.515164         132.924514            2      False
# 5                 0.602385          31.577895            1      False
# 6               362.020279          44.529352            2      False
# 7               149.501869          32.103163            1      False
# 8               141.727287          26.143192            1      False
# 9                 0.009884           0.543953            3       True
# 10                0.026430           0.012013            2       True
# 11                     NaN          39.236059            2       True
# 12                     NaN          50.258835            1       True
# 13                     NaN          29.334701            2       True
# 14                     NaN           2.207673            1       True
# 15                     NaN           1.833230            2       True
# 16                     NaN           1.532850            1       True
# 17                     NaN           1.930640            1       True
#
#     fit_order
# 0           9
# 1           7
# 2           3
# 3           5
# 4           8
# 5           4
# 6           6
# 7           1
# 8           2
# 9          18
# 10         14
# 11         16
# 12         12
# 13         17
# 14         13
# 15         15
# 16         10
# 17         11

# %%
submission['target'] = predictor.predict(test)
submission.to_csv('submission_autogluon.csv')
# Out:
# /opt/conda/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## AutoKeras

# %%
# !pip install -q autokeras
import tensorflow as tf
import autokeras as ak

# %%
train_size = int(train.shape[0] * 0.2)
train[:train_size].to_csv("train_new.csv", index=False)
train[train_size:].to_csv("test_new.csv", index=False)
train_file_path = "train_new.csv"
test_file_path = "test_new.csv"

# %%
reg = ak.StructuredDataRegressor(overwrite=True, 
                                 max_trials=5,
                                 loss="mean_squared_error",
                                 )  
reg.fit(train_file_path, 
        "target", 
        epochs=10,
        )

# %%
print(reg.evaluate(test_file_path, "target"))

# %%
submission['target'] = reg.predict(test)
submission.to_csv('submission_autokeras.csv')

# %% [markdown]
# ## PyCaret
